# %%
from bs4 import BeautifulSoup
import requests
import time, os
import pandas as pd
from IPython.core.display import display, HTML
import re
from re import sub
from decimal import Decimal
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from iso3166 import countries
import numpy as np

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
url_search = "https://www.boxofficemojo.com/chart/top_lifetime_gross/"
#youtube_query = youtube_search + query.replace(' ', '+')

#youtube_query

# %%
#page = requests.get(youtube_query).text
#soup = BeautifulSoup(page, 'html5lib')

# %%
#soup.find('div', id='contents')

# %%
driver = webdriver.Chrome(chromedriver)

# %%
driver.get(url_search)
#driver()

# %%
movie_title_click = driver.find_elements_by_xpath(
    '//a[contains(@href, "/title/tt")]'
)
#movie_title_click[199].click()

# %%
''''
movie_title_click = driver.find_elements_by_xpath(
    '//a[contains(@href, "/title/tt")]'
)
for idx, movie in enumerate(movie_title_click):
    movie_title_click = driver.find_elements_by_xpath(
    '//a[contains(@href, "/title/tt")]')
    movie_title_click[idx].click()
    driver.back()
    time.sleep(2)
    if idx >= 3:
        next_page = driver.find_element_by_partial_link_text("Next page")
        next_page.click()
        time.sleep(2)
    if idx == 5:
        time.sleep(3)
        break
'''
# Out:
# '\'\nmovie_title_click = driver.find_elements_by_xpath(\n    \'//a[contains(@href, "/title/tt")]\'\n)\nfor idx, movie in enumerate(movie_title_click):\n    movie_title_click = driver.find_elements_by_xpath(\n    \'//a[contains(@href, "/title/tt")]\')\n    movie_title_click[idx].click()\n    driver.back()\n    time.sleep(2)\n    if idx >= 3:\n        next_page = driver.find_element_by_partial_link_text("Next page")\n        next_page.click()\n        time.sleep(2)\n    if idx == 5:\n        time.sleep(3)\n        break\n'

# %%
#Movie Name, 
#Domestic Opening 
#Budget, MPAA, Running Time, Genres, Markets, Domestic Distributor
#Release Date Year?, Release Date Month, Director, In Release, Opening Theatre Release

# %%
#opening theatre  = click movie title -> original release -> domestic -> summary details

# %%
movie_name_list = [] ###
budget_list = [] ###
MPAA_list = [] ###
run_time_list = [] ###
genre_list = [] ###
markets_list = [] ###
production_co_list = [] ###
release_month_list = [] ###
#director_list = []
no_of_releases = [] ###
in_theatres_list_duration = [] 
opening_list = [] ##
widest_release_list = [] 
world_revenue_list = [] ###

# %%
#driver.quit()

# %%
url ='https://www.boxofficemojo.com/title/tt2488496/?ref_=bo_tt_tab#tabs' 

response = requests.get(url)

page = response.text

soup = BeautifulSoup(page, "lxml")

# %%
'''
movie_name_list = [] ###
budget_list = [] ###
MPAA_list = [] ###
run_time_list = [] ###
genre_list = [] ###
markets_list = [] ###
production_co_list = [] ###
release_month_list = [] ###
#director_list = []
no_of_releases = [] ###
in_theatres_list_duration = []
opening_theatre_list = []
world_revenue_list = [] ###
'''

movie_title_click = driver.find_elements_by_xpath(
    '//a[contains(@href, "/title/tt")]'
)
count = 174
#for idx, movie in enumerate(movie_title_click):
while count < 1000:
    movie_title_click = driver.find_elements_by_xpath(
    '//a[contains(@href, "/title/tt")]')
    movie_title_click[count].click()
    
    #getting URL
    url = driver.current_url
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page, "lxml")
    
    #Movie Title
    title =soup.find_all(name = "meta")
    title = str(title[3])
    title = title.split('"')[1]
    movie_name_list.append(title)
    
    #Budget
    if "Budget" not in page:
        budget_list.append("N/A")
    else:
        budget = soup.find_all("span", class_ = "money")
        if len(budget) < 5:
            budget = budget[2].text
            budget = float(Decimal(sub(r'[^\d.]', '', budget)))
            budget_list.append(budget)
        else:
            budget = budget[4].text
            budget = float(Decimal(sub(r'[^\d.]', '', budget)))
            budget_list.append(budget)
    
    #MPAA
    if "MPAA" not in page:
        MPAA_list.append("N/A")
    else:
        MPAA_regex = re.compile('MPAA')
        soup.find(text=MPAA_regex)
        MPAA_string = soup.find(text=re.compile('MPAA'))
        MPAA = MPAA_string.findNext()
        MPAA_list.append(MPAA)
    
    #RT
    if "Running Time" not in page:
        run_time_list.append("N/A")
    else:
        run_time = re.compile('Running Time')
        rt_string = soup.find(text=re.compile('Running Time'))
        rt = rt_string.findNext().text
        rt = rt.split()
        if len(rt) > 2:
            minutes = int(rt[0])*60 + int(rt[2])
            run_time_list.append(minutes)
        else:
            minutes = int(rt[0])*60
            run_time_list.append(minutes)
    
    #Genre
    if "Genres" not in page:
        genre_list.append("N/A")
    else:
        genre = re.compile('Genres')
        genre_string = soup.find(text=re.compile('Genres'))
        genre = genre_string.findNext().text
        genre = "\n".join(genre.split())
        genre = genre.replace("\n", ",").split()
        genre_list.append(genre)
    
    #Production C0
    if "Domestic Distributor" not in page:
        production_co_list.append("N/A")
    else:
        production_co = re.compile
        production_co = re.compile('Domestic Distributor')
        production_co = soup.find(text=re.compile('Domestic Distributor'))
        production_co = production_co.findNext().text
        production_co = (production_co.split("See")[0])
        production_co_list.append(production_co)
    
    #Release Month
    if "Earliest Release Date" not in page:
        release_month_list.append("N/A")
    else:
        release_month = re.compile
        release_month = re.compile('Earliest Release Date')
        release_month = soup.find(text=re.compile('Earliest Release Date'))
        release_month = release_month.findNext().text
        release_month = release_month.split(" ")[0]
        release_month_list.append(release_month)
    
    #Of Markets Released
    markets = 1
    tr_list = soup.find_all("tr")
    for i in tr_list:
        for c in countries:
            if c.name in i.text:
                markets += 1 
    no_of_markets = markets
    markets_list.append(no_of_markets)
    
    #No of Releases
    release_list =soup.find_all("select" , id = "releasegroup-picker-navSelector")
    releases = len((release_list[0].text).split("Re")) - 2
    no_of_releases.append(releases)
    
    #world revenue
    worldwide = soup.find_all("span", class_ = "money")
    worldwide = worldwide[2].text
    worldwide = float(Decimal(sub(r'[^\d.]', '', worldwide)))
    world_revenue_list.append(worldwide)
    
    
    #navigating to other parts of the page for additional features
    select_release = Select(driver.find_element_by_id("releasegroup-picker-navSelector"))
    select_release.select_by_visible_text("Original Release")

    select_territory = Select(driver.find_element_by_xpath("//select[@name='release-picker-navSelector']"))
    select_territory.select_by_visible_text("Domestic")
    
    url = driver.current_url
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page, "lxml")
    
    #Opening
    if "Opening" not in page:
        opening_list.append('N/A')
    else:
        opening = re.compile
        opening = re.compile('Opening')
        opening = soup.find(text=re.compile('Opening'))
        opening = opening.findNext().text
        o = opening.split("\n")
        o = o[0]  
        #o = float(Decimal(sub(r'[^\d.]', '', o)))
        opening_list.append(o)
    
    #in release
    if "In Release" not in page:
        release_monnth_list.append("N/A")
    else:
        in_release = re.compile
        in_release = re.compile('In Release')
        in_release = soup.find(text=re.compile('In Release'))
        in_release = in_release.findNext().text
        in_release = in_release.split(" ")
        in_release = int(in_release[0])
        in_theatres_list_duration.append(in_release)
    
    #wildest release
    if "Widest Release" not in page:
        widest_release_list.append("N/A")
    else:
        widest_release = re.compile
        widest_release = re.compile('Widest Release')
        widest_release = soup.find(text=re.compile('Widest Release'))
        widest_release = widest_release.findNext().text
        widest_release = widest_release.split(" ")
        widest_release = int(widest_release[0].replace(",",""))
        widest_release_list.append(widest_release)
    
    count+=1
    driver.back()
    driver.back()
    driver.back()
    #time.sleep(1)
    #going to next page
    if count == 200 or count == 399 or count == 599 or count == 799:
        next_page = driver.find_element_by_partial_link_text("Next page")
        next_page.click()
        driver.get(driver.current_url)
        movie_title_click = driver.find_elements_by_xpath(
        '//a[contains(@href, "/title/tt")]')
        count = 0
        
    if count == 181:
        break
            
    if len(movie_name_list) == 1000:
        '''
        print(movie_name_list)
        print(budget_list)
        print(MPAA_list)
        print(run_time_list)
        print(genre_list)
        print(production_co_list)
        print(release_month_list)
        print(markets_list)
        print(no_of_releases)
        print(world_revenue_list)
        '''
        break

# %%
in_release = re.compile
in_release = re.compile('In Release')
in_release = soup.find(text=re.compile('In Release'))
in_release = in_release.findNext().text
in_release = in_release.split(" ")
in_release = in_release[0]
# Out:
# 2020039514020.0

# %%
print(len(movie_name_list))
print(len(budget_list))
print(len(MPAA_list))
print(len(run_time_list))
print(len(genre_list))
print(len(production_co_list))
print(len(release_month_list))
print(len(markets_list))
print(len(no_of_releases))
print(len(world_revenue_list))
print(len(opening_list))
print(len(in_theatres_list_duration))
print(len(widest_release_list))
# Out:
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000

# %%
'''
runtime_regex = re.compile('MPAA')
soup.find(text=runtime_regex)
'''
#opening_list.append("$364,244")
in_theatres_list_duration.append(1072)
widest_release_list.append("N/A")
#in_theatres_list_duration

# %%
#rt_string = soup.find(text=re.compile('MPAA'))
#rt_string.findNext().text
movie_name_list
# Out:
# ['Star Wars: Episode VII - The Force Awakens',
#  'Avengers: Endgame',
#  'Avatar',
#  'Black Panther',
#  'Avengers: Infinity War',
#  'Titanic',
#  'Jurassic World',
#  'The Avengers',
#  'Star Wars: Episode VIII - The Last Jedi',
#  'Incredibles 2',
#  'The Lion King',
#  'The Dark Knight',
#  'Rogue One: A Star Wars Story',
#  'Star Wars: Episode IX - The Rise of Skywalker',
#  'Beauty and the Beast',
#  'Finding Dory',
#  'Frozen II',
#  'Star Wars: Episode I - The Phantom Menace',
#  'Star Wars: Episode IV - A New Hope',
#  'Avengers: Age of Ultron',
#  'The Dark Knight Rises',
#  'Shrek 2',
#  'E.T. the Extra-Terrestrial',
#  'Toy Story 4',
#  'Captain Marvel',
#  'The Hunger Games: Catching Fire',
#  "Pirates of the Caribbean: Dead Man's Chest",
#  'The Lion King',
#  'Jurassic World: Fallen Kingdom',
#  'Toy Story 3',
#  'Wonder Woman',
#  'Iron Man 3',
#  'Captain America: Civil War',
#  'The Hunger Games',
#  'Spider-Man',
#  'Jumanji: Welcome to the Jungle',
#  'Jurassic Park',
#  'Transformers: Revenge of the Fallen',
#  'Frozen',
#  'Spider-Man: Far from Home',
#  'Guardians of the Galaxy Vol. 2',
#  'Harry Potter and the Deathly Hallows: Part 2',
#  'Finding Nemo',
#  'Star Wars: Episode III - Revenge of the Sith',
#  'The Lord of the Rings: The Return of the King',
#  'Spider-Man 2',
#  'The Passion of the Christ',
#  'The Secret Life of Pets',
#  'Despicable Me 2',
#  'The Jungle Book',
#  'Deadpool',
#  'Inside Out',
#  'Aladdin',
#  'Furious 7',
#  'Transformers: Dark of the Moon',
#  'American Sniper',
#  'The Lord of the Rings: The Two Towers',
#  'Zootopia',
#  'The Hunger Games: Mockingjay - Part 1',
#  'Spider-Man 3',
#  'Minions',
#  'Joker',
#  'Aquaman',
#  'Spider-Man: Homecoming',
#  'Alice in Wonderland',
#  'Guardians of the Galaxy',
#  'Forrest Gump',
#  'Batman v Superman: Dawn of Justice',
#  'It',
#  'Suicide Squad',
#  'Deadpool 2',
#  'Shrek the Third',
#  'Jumanji: The Next Level',
#  'Transformers',
#  'Iron Man',
#  "Harry Potter and the Sorcerer's Stone",
#  'Indiana Jones and the Kingdom of the Crystal Skull',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'Thor: Ragnarok',
#  'Iron Man 2',
#  'Star Wars: Episode II - Attack of the Clones',
#  "Pirates of the Caribbean: At World's End",
#  'Star Wars: Episode VI - Return of the Jedi',
#  'Independence Day',
#  'Pirates of the Caribbean: The Curse of the Black Pearl',
#  'Skyfall',
#  'The Hobbit: An Unexpected Journey',
#  'Harry Potter and the Half-Blood Prince',
#  'The Twilight Saga: Eclipse',
#  'The Twilight Saga: New Moon',
#  'Harry Potter and the Deathly Hallows: Part 1',
#  'The Sixth Sense',
#  'Up',
#  'Star Wars: Episode V - The Empire Strikes Back',
#  'Inception',
#  'Harry Potter and the Order of the Phoenix',
#  'The Twilight Saga: Breaking Dawn - Part 2',
#  'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#  'Man of Steel',
#  'Monsters, Inc.',
#  'Harry Potter and the Goblet of Fire',
#  'Home Alone',
#  'The Hunger Games: Mockingjay - Part 2',
#  'The Matrix Reloaded',
#  'The Twilight Saga: Breaking Dawn - Part 1',
#  'Meet the Fockers',
#  'The Hangover',
#  'Gravity',
#  'The Grinch',
#  'Sing',
#  'Monsters University',
#  'Shrek',
#  'Despicable Me 3',
#  'Harry Potter and the Chamber of Secrets',
#  'The Amazing Spider-Man',
#  'The Incredibles',
#  'Jaws',
#  'How the Grinch Stole Christmas',
#  'Captain America: The Winter Soldier',
#  'The Hobbit: The Desolation of Smaug',
#  'The Lego Movie',
#  'Star Trek',
#  'I Am Legend',
#  'The Blind Side',
#  'The Hobbit: The Battle of the Five Armies',
#  'The Hangover Part II',
#  'Despicable Me',
#  'Batman',
#  'Night at the Museum',
#  'Men in Black',
#  'Harry Potter and the Prisoner of Azkaban',
#  'Moana',
#  'Indiana Jones and the Raiders of the Lost Ark',
#  'Toy Story 2',
#  'Transformers: Age of Extinction',
#  'Cars',
#  'Ghostbusters',
#  'Bruce Almighty',
#  'Twister',
#  'My Big Fat Greek Wedding',
#  'Maleficent',
#  'Pirates of the Caribbean: On Stranger Tides',
#  'Shrek Forever After',
#  'Fast &amp; Furious 6',
#  'Brave',
#  'Oz the Great and Powerful',
#  'Beverly Hills Cop',
#  'X-Men: The Last Stand',
#  'War of the Worlds',
#  'Fantastic Beasts and Where to Find Them',
#  'X-Men: Days of Future Past',
#  'Cast Away',
#  'The Exorcist',
#  'Doctor Strange',
#  'The Lost World: Jurassic Park',
#  'Justice League',
#  'Star Trek Into Darkness',
#  'The Martian',
#  'Signs',
#  'Hancock',
#  'The Bourne Ultimatum',
#  'Logan',
#  'Rush Hour 2',
#  'The Fate of the Furious',
#  'WALL·E',
#  'Toy Story',
#  'Big Hero 6',
#  'Mission: Impossible - Fallout',
#  'National Treasure: Book of Secrets',
#  'Alvin and the Chipmunks: The Squeakquel',
#  'Mrs. Doubtfire',
#  'Beauty and the Beast',
#  'Ted',
#  'King Kong',
#  'Ghost',
#  'How to Train Your Dragon',
#  'The Da Vinci Code',
#  'Aladdin',
#  'Alvin and the Chipmunks',
#  'Saving Private Ryan',
#  'Bohemian Rhapsody',
#  'Ant-Man and the Wasp',
#  "Madagascar 3: Europe's Most Wanted",
#  'Kung Fu Panda',
#  'Mission: Impossible II',
#  'A Star Is Born',
#  'X2: X-Men United',
#  'The Lorax',
#  'Solo: A Star Wars Story',
#  'Venom',
#  'Austin Powers in Goldmember',
#  'It Chapter Two',
#  'Back to the Future',
#  '300',
#  'Coco',
#  'Fast Five',
#  'Mission: Impossible - Ghost Protocol',
#  'Wedding Crashers',
#  'Sherlock Holmes',
#  'Dawn of the Planet of the Apes',
#  'Batman Begins',
#  'Charlie and the Chocolate Factory',
#  'Ratatouille',
#  'Thor: The Dark World',
#  'Bad Boys for Life',
#  'Austin Powers: The Spy Who Shagged Me',
#  'Terminator 2: Judgment Day',
#  'The Amazing Spider-Man 2',
#  'World War Z',
#  'The Mummy Returns',
#  'Armageddon',
#  'Cinderella',
#  'Ralph Breaks the Internet',
#  'Gone with the Wind',
#  'Tangled',
#  'Godzilla',
#  'Superman Returns',
#  'Spectre',
#  'Pearl Harbor',
#  'Monsters vs. Aliens',
#  'Shang-Chi and the Legend of the Ten Rings',
#  'Happy Feet',
#  'Indiana Jones and the Last Crusade',
#  'Ice Age: Dawn of the Dinosaurs',
#  'Ice Age: The Meltdown',
#  'Mission: Impossible - Rogue Nation',
#  'Twilight',
#  'Men in Black II',
#  'Madagascar',
#  '22 Jump Street',
#  'Cars 2',
#  'Teenage Mutant Ninja Turtles',
#  'Spider-Man: Into the Spider-Verse',
#  'Grease',
#  'Dunkirk',
#  'Wreck-It Ralph',
#  'A Quiet Place',
#  'Interstellar',
#  'The Polar Express',
#  'Gladiator',
#  'The Croods',
#  'Sherlock Holmes: A Game of Shadows',
#  'The Day After Tomorrow',
#  'Mr. &amp; Mrs. Smith',
#  'Snow White and the Seven Dwarfs',
#  'Pitch Perfect 2',
#  'Dances with Wolves',
#  'Batman Forever',
#  'The Fugitive',
#  'The Revenant',
#  'Black Widow',
#  "Ocean's Eleven",
#  'The Simpsons Movie',
#  'What Women Want',
#  'The Perfect Storm',
#  'Lincoln',
#  'Liar Liar',
#  'Jurassic Park III',
#  'Thor',
#  'Mission: Impossible',
#  'Top Gun',
#  'Ant-Man',
#  'Planet of the Apes',
#  'Madagascar: Escape 2 Africa',
#  'X-Men Origins: Wolverine',
#  'Indiana Jones and the Temple of Doom',
#  'Hitch',
#  'Men in Black 3',
#  'Pretty Woman',
#  'Home',
#  'Night at the Museum: Battle of the Smithsonian',
#  'Tootsie',
#  'How to Train Your Dragon 2',
#  'Rise of the Planet of the Apes',
#  'Captain America: The First Avenger',
#  'Elf',
#  'The Karate Kid',
#  "There's Something About Mary",
#  'Ice Age',
#  'The Bourne Supremacy',
#  'Get Out',
#  'The Lego Batman Movie',
#  'Us',
#  'The Boss Baby',
#  'Crocodile Dundee',
#  'Crazy Rich Asians',
#  'The Greatest Showman',
#  'Fast &amp; Furious Presents: Hobbs &amp; Shaw',
#  'Apollo 13',
#  'Home Alone 2: Lost in New York',
#  'National Treasure',
#  'F9: The Fast Saga',
#  'Air Force One',
#  'Rain Man',
#  'Pirates of the Caribbean: Dead Men Tell No Tales',
#  'TRON: Legacy',
#  'Mary Poppins Returns',
#  'The Matrix',
#  'True Grit',
#  'Tarzan',
#  'John Wick: Chapter 3 - Parabellum',
#  'A Beautiful Mind',
#  'Chicago',
#  'The Help',
#  'Hotel Transylvania 2',
#  'Hidden Figures',
#  'Bridesmaids',
#  'Quantum of Solace',
#  'Wild Hogs',
#  'Kong: Skull Island',
#  'Three Men and a Baby',
#  'Gone Girl',
#  'Hotel Transylvania 3: Summer Vacation',
#  'Casino Royale',
#  'Meet the Parents',
#  'Fifty Shades of Grey',
#  '2012',
#  'Robin Hood: Prince of Thieves',
#  'Knives Out',
#  'Kung Fu Panda 2',
#  'Hannibal',
#  'Catch Me If You Can',
#  'The Proposal',
#  'The Pursuit of Happyness',
#  'Big Daddy',
#  'Clash of the Titans',
#  'The SpongeBob Movie: Sponge Out of Water',
#  'Batman Returns',
#  'Django Unchained',
#  "A Bug's Life",
#  'Jason Bourne',
#  'Grown Ups',
#  'The Waterboy',
#  'Ice Age: Continental Drift',
#  'Straight Outta Compton',
#  'Die Another Day',
#  'Shark Tale',
#  'How to Train Your Dragon: The Hidden World',
#  'A Quiet Place Part II',
#  'The Heat',
#  'Fantastic Beasts: The Crimes of Grindelwald',
#  'Halloween',
#  'The Sound of Music',
#  '1917',
#  'The Secret Life of Pets 2',
#  'Star Trek Beyond',
#  'The Firm',
#  'The Longest Yard',
#  'X-Men',
#  'Scary Movie',
#  'Fatal Attraction',
#  'Who Framed Roger Rabbit',
#  'The Sting',
#  'What Lies Beneath',
#  'X-Men: Apocalypse',
#  'The Mummy',
#  'Snow White and the Huntsman',
#  'San Andreas',
#  'Fast &amp; Furious',
#  'Over the Hedge',
#  'Fantastic Four',
#  'Horton Hears a Who!',
#  'Mad Max: Fury Road',
#  'Jerry Maguire',
#  'Trolls',
#  'Beverly Hills Cop II',
#  'Gremlins',
#  'Scooby-Doo',
#  'Cars 3',
#  'Sex and the City',
#  'Runaway Bride',
#  'La La Land',
#  'Divergent',
#  'Rambo: First Blood Part II',
#  "We're the Millers",
#  'Terminator 3: Rise of the Machines',
#  "Daddy's Home",
#  'G.I. Joe: The Rise of Cobra',
#  'Neighbors',
#  'American Hustle',
#  'Puss in Boots',
#  'Sonic the Hedgehog',
#  'Les Misérables',
#  'Knocked Up',
#  'As Good as It Gets',
#  'Little Fockers',
#  'Megamind',
#  'Hotel Transylvania',
#  'Talladega Nights: The Ballad of Ricky Bobby',
#  'Gran Torino',
#  'Lethal Weapon 2',
#  'War for the Planet of the Apes',
#  'X-Men: First Class',
#  'Paul Blart: Mall Cop',
#  'True Lies',
#  'Lilo &amp; Stitch',
#  'The Santa Clause',
#  'The Meg',
#  'American Pie 2',
#  'Taken',
#  'One Hundred and One Dalmatians',
#  'The Great Gatsby',
#  'I, Robot',
#  'Lethal Weapon 3',
#  'The Fast and the Furious',
#  'Mamma Mia!',
#  'Doctor Dolittle',
#  'Pokémon Detective Pikachu',
#  'Rio',
#  'Kung Fu Panda 3',
#  'Juno',
#  'Marley &amp; Me',
#  'The Smurfs',
#  'Once Upon a Time... In Hollywood',
#  'xXx',
#  'The Jungle Book',
#  'The Chronicles of Narnia: Prince Caspian',
#  "National Lampoon's Animal House",
#  'Pocahontas',
#  'A Few Good Men',
#  'Slumdog Millionaire',
#  'Rush Hour',
#  'The Blair Witch Project',
#  'Deep Impact',
#  'Shazam!',
#  "Ocean's Eight",
#  'Rush Hour 3',
#  "Look Who's Talking",
#  'Stuart Little',
#  'Taken 2',
#  'Sister Act',
#  'The Matrix Revolutions',
#  'The Santa Clause 2',
#  "The King's Speech",
#  'Cheaper by the Dozen',
#  'Bad Boys II',
#  'Platoon',
#  '21 Jump Street',
#  'Good Will Hunting',
#  'Split',
#  'A Christmas Carol',
#  'Dinosaur',
#  'Ready Player One',
#  'The Conjuring',
#  'Click',
#  'The Green Mile',
#  'Ransom',
#  'Godzilla',
#  '101 Dalmatians',
#  'Argo',
#  'Anger Management',
#  'Chicken Little',
#  'Teenage Mutant Ninja Turtles: The Movie',
#  'Close Encounters of the Third Kind',
#  'Patch Adams',
#  'The Godfather',
#  'Ride Along',
#  'The Incredible Hulk',
#  'Live Free or Die Hard',
#  'Wanted',
#  'Identity Thief',
#  'Superman',
#  'The Rock',
#  'Mission: Impossible III',
#  'Grown Ups 2',
#  'Troy',
#  'Angels &amp; Demons',
#  'Alvin and the Chipmunks: Chipwrecked',
#  'Bringing Down the House',
#  'The Wolverine',
#  'Wonder',
#  'The Departed',
#  'Hulk',
#  'Silver Linings Playbook',
#  'Minority Report',
#  'Fantastic 4: Rise of the Silver Surfer',
#  'The Last Airbender',
#  'Rio 2',
#  'Lara Croft: Tomb Raider',
#  'The Silence of the Lambs',
#  'Honey, I Shrunk the Kids',
#  'The Flintstones',
#  'Lethal Weapon 4',
#  'Get Smart',
#  'The Divergent Series: Insurgent',
#  'The Peanuts Movie',
#  'Transformers: The Last Knight',
#  'American Gangster',
#  'American Beauty',
#  'An Officer and a Gentleman',
#  'The Ring',
#  'The Nutty Professor',
#  'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan',
#  'Ghostbusters',
#  'Kingsman: The Secret Service',
#  'Robots',
#  'Coming to America',
#  'Crouching Tiger, Hidden Dragon',
#  'Shutter Island',
#  'Into the Woods',
#  'Rocky IV',
#  'Enchanted',
#  'The Curious Case of Benjamin Button',
#  'Central Intelligence',
#  'Anchorman 2: The Legend Continues',
#  'Sweet Home Alabama',
#  'Bumblebee',
#  'Dumb and Dumber',
#  '2 Fast 2 Furious',
#  "My Best Friend's Wedding",
#  'Super 8',
#  'The World Is Not Enough',
#  'Sleepless in Seattle',
#  'Smokey and the Bandit',
#  'Lucy',
#  'The Legend of Tarzan',
#  'Bee Movie',
#  'Prometheus',
#  'Safe House',
#  'Mr. Deeds',
#  'The Truman Show',
#  'Erin Brockovich',
#  "Ocean's Twelve",
#  'Terminator Salvation',
#  "Charlie's Angels",
#  'Tomorrow Never Dies',
#  'Lone Survivor',
#  'Sully',
#  'Rocky III',
#  'The Vow',
#  'Life of Pi',
#  'The Fault in Our Stars',
#  'Cloudy with a Chance of Meatballs',
#  'The Devil Wears Prada',
#  "Something's Gotta Give",
#  'Traffic',
#  'The Birdcage',
#  'City Slickers',
#  'Good Morning, Vietnam',
#  'Rango',
#  'Nutty Professor II: The Klumps',
#  'The Good Dinosaur',
#  'G.I. Joe: Retaliation',
#  'Clear and Present Danger',
#  'The Hunt for Red October',
#  'The Bodyguard',
#  "Wayne's World",
#  'The Bourne Identity',
#  'Superbad',
#  'Speed',
#  '50 First Dates',
#  'Mamma Mia! Here We Go Again',
#  'Mulan',
#  'Inglourious Basterds',
#  'Seabiscuit',
#  'Van Helsing',
#  'Four Christmases',
#  'I Now Pronounce You Chuck &amp; Larry',
#  'The Mask',
#  'Cloudy with a Chance of Meatballs 2',
#  'Hook',
#  'Blazing Saddles',
#  'Walk the Line',
#  'G-Force',
#  'Total Recall',
#  'On Golden Pond',
#  'The Other Guys',
#  'Fahrenheit 9/11',
#  'Back to the Future Part II',
#  'The Sum of All Fears',
#  'Hairspray',
#  'The Break-Up',
#  'A Series of Unfortunate Events',
#  'Blades of Glory',
#  'Salt',
#  'Basic Instinct',
#  'Now You See Me',
#  'Ford v Ferrari',
#  "Big Momma's House",
#  'Die Hard 2',
#  'Horrible Bosses',
#  'The Nun',
#  'Rocky',
#  'Jackass 3D',
#  "Ocean's Thirteen",
#  'S.W.A.T.',
#  'The Wolf of Wall Street',
#  '8 Mile',
#  'Double Jeopardy',
#  "Lee Daniels' The Butler",
#  'Green Lantern',
#  'Notting Hill',
#  'The Towering Inferno',
#  "You've Got Mail",
#  'Ghost Rider',
#  'Remember the Titans',
#  'Creed II',
#  'District 9',
#  'Unbroken',
#  'Peter Rabbit',
#  'Big',
#  'Girls Trip',
#  'Jungle Cruise',
#  'The Karate Kid Part II',
#  'American Graffiti',
#  'Free Guy',
#  'Dumbo',
#  'Fifty Shades Darker',
#  'Dodgeball: A True Underdog Story',
#  'The Village',
#  'Bolt',
#  'Maleficent: Mistress of Evil',
#  'Wild Wild West',
#  'Night at the Museum: Secret of the Tomb',
#  'Magic Mike',
#  'The Addams Family',
#  'The Patriot',
#  'Bad Moms',
#  'The Bourne Legacy',
#  'The Pacifier',
#  'Dr. Dolittle 2',
#  'The Rocky Horror Picture Show',
#  "It's Complicated",
#  'Spy Kids',
#  'Ghostbusters II',
#  'Face/Off',
#  'The Hangover Part III',
#  'Twins',
#  'Spy Kids 3-D: Game Over',
#  'Doctor Zhivago',
#  'Enemy of the State',
#  'The Little Mermaid',
#  'Mr. Peabody &amp; Sherman',
#  "Porky's",
#  'The Last Samurai',
#  'Glass',
#  'Spy',
#  'Tropic Thunder',
#  'Godzilla: King of the Monsters',
#  "Valentine's Day",
#  'The Grudge',
#  'Fun with Dick and Jane',
#  'Freaky Friday',
#  'Trainwreck',
#  'Bedtime Stories',
#  'Scary Movie 3',
#  'Creed',
#  'Star Trek IV: The Voyage Home',
#  'The 40-Year-Old Virgin',
#  'Crocodile Dundee II',
#  'Couples Retreat',
#  "One Flew Over the Cuckoo's Nest",
#  'A Time to Kill',
#  'Black Hawk Down',
#  'Terms of Endearment',
#  'Ace Ventura: When Nature Calls',
#  'The Upside',
#  'The Princess Diaries',
#  'Superman II',
#  'Little Women',
#  'Hop',
#  'Pulp Fiction',
#  'Paranormal Activity',
#  'Baby Driver',
#  'A League of Their Own',
#  'Epic',
#  'Watchmen',
#  'The Angry Birds Movie',
#  'Batman &amp; Robin',
#  'Captain Phillips',
#  'Black Swan',
#  'Analyze This',
#  'Chicken Run',
#  'Miss Congeniality',
#  'Indecent Proposal',
#  'Driving Miss Daisy',
#  '300: Rise of an Empire',
#  'Love Story',
#  'GoldenEye',
#  'Kramer vs. Kramer',
#  'The Italian Job',
#  'How to Lose a Guy in 10 Days',
#  'The Lego Movie 2: The Second Part',
#  'The First Wives Club',
#  'Robin Hood',
#  'Interview with the Vampire: The Vampire Chronicles',
#  'George of the Jungle',
#  'Hustlers',
#  'The Graduate',
#  'Pitch Perfect 3',
#  'Phenomenon',
#  'American Wedding',
#  'Road to Perdition',
#  'The Princess and the Frog',
#  'The Chronicles of Narnia: The Voyage of the Dawn Treader',
#  'Daddy Day Care',
#  "Daddy's Home 2",
#  'Paranormal Activity 3',
#  'Journey 2: The Mysterious Island',
#  'The Mule',
#  'Dick Tracy',
#  'Rise of the Guardians',
#  'Dreamgirls',
#  '9 to 5',
#  'Independence Day: Resurgence',
#  'The Expendables',
#  'Scream',
#  'Just Go with It',
#  'Murder on the Orient Express',
#  "The General's Daughter",
#  'The Aviator',
#  'American Pie',
#  'Daredevil',
#  'The Girl with the Dragon Tattoo',
#  'The Mummy: Tomb of the Dragon Emperor',
#  'The Conjuring 2',
#  'The Maze Runner',
#  'In the Line of Fire',
#  'Butch Cassidy and the Sundance Kid',
#  'Mary Poppins',
#  'Bambi',
#  'Annabelle: Creation',
#  'The Equalizer 2',
#  'Bad Grandpa',
#  'Pacific Rim',
#  'Journey to the Center of the Earth',
#  'Gone in 60 Seconds',
#  'Maverick',
#  'Sleeping with the Enemy',
#  'The Equalizer',
#  'This Is the End',
#  'Eagle Eye',
#  'The Prince of Egypt',
#  'Scream 2',
#  'Stir Crazy',
#  'Eraser',
#  'Noah',
#  'Unforgiven',
#  'The Cat in the Hat',
#  'Con Air',
#  'Sleepy Hollow',
#  'Rampage',
#  'Collateral',
#  'Contact',
#  "Charlie's Angels: Full Throttle",
#  'The Pelican Brief',
#  'The Addams Family',
#  'Vanilla Sky',
#  'Godzilla vs. Kong',
#  'Arrival',
#  'Due Date',
#  'Jumanji',
#  'The Rugrats Movie',
#  'Million Dollar Baby',
#  'Airport',
#  'A Wrinkle in Time',
#  'Step Brothers',
#  'Evan Almighty',
#  'Fifty Shades Freed',
#  'Casper',
#  'Shakespeare in Love',
#  'Bad Teacher',
#  'Yogi Bear',
#  'Cowboys &amp; Aliens',
#  'Kingsman: The Golden Circle',
#  'Edge of Tomorrow',
#  'The Hunchback of Notre Dame',
#  'Se7en',
#  'Parenthood',
#  "You Don't Mess with the Zohan",
#  'Passengers',
#  'Die Hard with a Vengeance',
#  'Gnomeo &amp; Juliet',
#  'Christopher Robin',
#  'Hercules',
#  'Olympus Has Fallen',
#  'The Green Hornet',
#  'Date Night',
#  'The Color Purple',
#  'Meet the Robinsons']

# %%
#run_time = re.compile('Running Time')
#rt_string = soup.find(text=re.compile('Running Time'))
#rt = rt_string.findNext().text

# %%
#rt = rt.split()
#minutes = int(rt[0])*60 + int(rt[2])
#type(minutes)

# %%
#title =soup.find_all(name = "meta")
#title = str(title[3])
#title

# %%
#release_list =soup.find_all("select" , id = "releasegroup-picker-navSelector")

# %%
#for i in release_list:
 #   print(i.text)
 #   print(1)

# %%
#releases = len((release_list[0].text).split("Re")) - 2

# %%
#releases

# %%
# Out:
# '$17,814,2592,302'

# %%
#driver.quit()

# %%
#production_co = re.compile
#production_co = re.compile('Domestic Distributor')
#production_co = soup.find(text=re.compile('Domestic Distributor'))
#production_co = production_co.findNext().text

# %%
#production_co = (production_co.split("See")[0])

# %%
#production_co

# %%
'''
release_month = re.compile
release_month = re.compile('Earliest Release Date')
release_month = soup.find(text=re.compile('Earliest Release Date'))
release_month = release_month.findNext().text
release_month = release_month.split(" ")[0]
'''
# Out:
# '\nrelease_month = re.compile\nrelease_month = re.compile(\'Earliest Release Date\')\nrelease_month = soup.find(text=re.compile(\'Earliest Release Date\'))\nrelease_month = release_month.findNext().text\nrelease_month = release_month.split(" ")[0]\n'

# %%
opening = re.compile
opening = re.compile('Opening')
opening = soup.find(text=re.compile('Opening'))
opening = opening.findNext().text
opening
# Out:
# '$257,698,183'

# %%
#tr_list = soup.find_all("tr")
title
# Out:
# 'Avengers: Infinity War'

# %%
'''
count = 1
for i in tr_list:
    for c in countries:
        if c.name in i.text:
            count += 1 
no_of_markets = count
'''

# %%
'''
worldwide = soup.find_all("span", class_ = "money")
worldwide = worldwide[2].text
worldwide = float(Decimal(sub(r'[^\d.]', '', worldwide)))
worldwide
print(len(movie_name_list))
print(len(budget_list))
print(len(MPAA_list))
print(len(run_time_list))
print(len(genre_list))
print(len(production_co_list))
print(len(release_month_list))
print(len(markets_list))
print(len(no_of_releases))
print(len(world_revenue_list))
print(len(opening_list))
print(len(in_theatres_list_duration))
print(len(widest_release_list))
'''

# %%
data = { "Budget" : budget_list, "MPAA" : MPAA_list, "Run Time": run_time_list,
        "Genre" : genre_list, "No of Markets": markets_list, "Production Co": production_co_list,
        "Release Month": release_month_list, "Release Count": no_of_releases, 
         "Opening Revenue": opening_list,
        "Length in Theatres(Days)": in_theatres_list_duration, "Widest Release": widest_release_list,
        "World Revenue": world_revenue_list 
       }

# %%
'''
movie_name_list = [] ###
budget_list = [] ###
MPAA_list = [] ###
run_time_list = [] ###
genre_list = [] ###
markets_list = [] ###
production_co_list = [] ###
release_month_list = [] ###
#director_list = []
no_of_releases = [] ###
in_theatres_list_duration = []
opening_theatre_list = []
world_revenue_list = [] ###
'''
len(data["Wildest Release"])
# Out:
# 155

# %%
df = pd.DataFrame(data, index = movie_name_list)

# %%
df.head(500)
# Out:
#                                                  Budget     MPAA  Run Time  \
# Star Wars: Episode VII - The Force Awakens  245000000.0  [PG-13]       138
# Avengers: Endgame                           356000000.0  [PG-13]       181
# Avatar                                      237000000.0  [PG-13]       162
# Black Panther                                       N/A  [PG-13]       134
# Avengers: Infinity War                              N/A  [PG-13]       149
# ...                                                 ...      ...       ...
# Robots                                       75000000.0     [PG]        91
# Coming to America                                   N/A      N/A       117
# Crouching Tiger, Hidden Dragon               17000000.0  [PG-13]       120
# Shutter Island                               80000000.0      [R]       138
# Into the Woods                               50000000.0     [PG]       125
#
#                                                                                         Genre  \
# Star Wars: Episode VII - The Force Awakens                          [Action,Adventure,Sci-Fi]
# Avengers: Endgame                                             [Action,Adventure,Drama,Sci-Fi]
# Avatar                                                      [Action,Adventure,Fantasy,Sci-Fi]
# Black Panther                                                       [Action,Adventure,Sci-Fi]
# Avengers: Infinity War                                              [Action,Adventure,Sci-Fi]
# ...                                                                                       ...
# Robots                                      [Adventure,Animation,Comedy,Family,Fantasy,Sci...
# Coming to America                                                            [Comedy,Romance]
# Crouching Tiger, Hidden Dragon                             [Action,Adventure,Fantasy,Romance]
# Shutter Island                                                             [Mystery,Thriller]
# Into the Woods                                       [Adventure,Comedy,Drama,Fantasy,Musical]
#
#                                             No of Markets  \
# Star Wars: Episode VII - The Force Awakens             56
# Avengers: Endgame                                      51
# Avatar                                                 71
# Black Panther                                          49
# Avengers: Infinity War                                 49
# ...                                                   ...
# Robots                                                 57
# Coming to America                                       1
# Crouching Tiger, Hidden Dragon                          7
# Shutter Island                                         53
# Into the Woods                                         53
#
#                                                                   Production Co  \
# Star Wars: Episode VII - The Force Awakens  Walt Disney Studios Motion Pictures
# Avengers: Endgame                           Walt Disney Studios Motion Pictures
# Avatar                                                    Twentieth Century Fox
# Black Panther                               Walt Disney Studios Motion Pictures
# Avengers: Infinity War                      Walt Disney Studios Motion Pictures
# ...                                                                         ...
# Robots                                                    Twentieth Century Fox
# Coming to America                                            Paramount Pictures
# Crouching Tiger, Hidden Dragon                           Sony Pictures Classics
# Shutter Island                                               Paramount Pictures
# Into the Woods                              Walt Disney Studios Motion Pictures
#
#                                            Release Month  Release Count  \
# Star Wars: Episode VII - The Force Awakens      December              3
# Avengers: Endgame                                  April              1
# Avatar                                          December              3
# Black Panther                                   February              2
# Avengers: Infinity War                             April              2
# ...                                                  ...            ...
# Robots                                             March              1
# Coming to America                                   June              1
# Crouching Tiger, Hidden Dragon                  December              2
# Shutter Island                                  February              2
# Into the Woods                                  December              1
#
#                                               Opening Revenue  \
# Star Wars: Episode VII - The Force Awakens  $247,966,6754,134
# Avengers: Endgame                           $357,115,0074,662
# Avatar                                       $77,025,4813,452
# Black Panther                               $202,003,9514,020
# Avengers: Infinity War                      $257,698,1834,474
# ...                                                       ...
# Robots                                       $36,045,3013,776
# Coming to America                            $21,404,4202,064
# Crouching Tiger, Hidden Dragon                     $663,20516
# Shutter Island                               $41,062,4402,991
# Into the Woods                               $31,051,9232,440
#
#                                             Length in Theatres(Days)  \
# Star Wars: Episode VII - The Force Awakens                       380
# Avengers: Endgame                                                250
# Avatar                                                           379
# Black Panther                                                    319
# Avengers: Infinity War                                           249
# ...                                                              ...
# Robots                                                           296
# Coming to America                                                186
# Crouching Tiger, Hidden Dragon                                   389
# Shutter Island                                                   316
# Into the Woods                                                   372
#
#                                            Widest Release  World Revenue
# Star Wars: Episode VII - The Force Awakens           4134   2.069522e+09
# Avengers: Endgame                                    4662   2.797501e+09
# Avatar                                               3461   2.847246e+09
# Black Panther                                        4084   1.347598e+09
# Avengers: Infinity War                               4474   2.048360e+09
# ...                                                   ...            ...
# Robots                                               3776   2.625115e+08
# Coming to America                                    2064   2.887523e+08
# Crouching Tiger, Hidden Dragon                       2027   2.135257e+08
# Shutter Island                                       3356   2.948057e+08
# Into the Woods                                       2833   2.129024e+08
#
# [500 rows x 12 columns]

# %%
'''

url_search1 = "https://www.boxofficemojo.com/title/tt2488496/"
driver1 = webdriver.Chrome(chromedriver)
driver1.get(url_search1)


'''

# %%
'''

select_release = Select(driver1.find_element_by_id("releasegroup-picker-navSelector"))
select_release.select_by_visible_text("Original Release")

select_territory = Select(driver1.find_element_by_xpath("//select[@name='release-picker-navSelector']"))

select_territory.select_by_visible_text("Domestic")


'''

# %%
df.to_csv("desktop")

# %%
#select_territory = Select(driver1.find_element_by_id("release-picker-navSelector"))
